# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hiral\Downloads\covid_19_data.csv")
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228326 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
df.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78103
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
df.shape
# Out:
# (306429, 8)

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  306429.000000  3.064290e+05  306429.000000  3.064290e+05
# mean   153215.000000  8.567091e+04    2036.403268  5.042029e+04
# std     88458.577156  2.775516e+05    6410.938048  2.015124e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     76608.000000  1.042000e+03      13.000000  1.100000e+01
# 50%    153215.000000  1.037500e+04     192.000000  1.751000e+03
# 75%    229822.000000  5.075200e+04    1322.000000  2.027000e+04
# max    306429.000000  5.863138e+06  112385.000000  6.399531e+06

# %%
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.tail()
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0

# %%
cat=[]
con=[]

for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['ObservationDate', 'Province/State', 'Country/Region', 'Last Update']

# %%
con
# Out:
# ['SNo', 'Confirmed', 'Deaths', 'Recovered']

# %%
df['Province/State'].mode()
# Out:
# 0    Unknown
# Name: Province/State, dtype: object

# %%
for i in con:
    print(f"Mean value of {i} is {df[i].mean()}")
# Out:
# Mean value of SNo is 153215.0
# Mean value of Confirmed is 85670.91155863185
# Mean value of Deaths is 2036.4032679674574
# Mean value of Recovered is 50420.28630449468

# %%
for i in df:
    if df[i].dtypes=="object":
        m=df[i].mode()[0]
        df[i]=df[i].fillna(m)
    else:
        me=df[i]
        df[i]=df[i]

# %%
import pandas as pd

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.isnull().sum()
# Out:
# SNo                0
# ObservationDate    0
# Province/State     0
# Country/Region     0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0
# dtype: int64

# %%
 df['ObservationDate'] = pd.to_datetime(df['ObservationDate'])

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
print("Number of duplicates:", df.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
import pandas as pd

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df_time = df.groupby('ObservationDate').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})

# %%
df_time
# Out:
#                   Confirmed     Deaths   Recovered
# ObservationDate
# 01/01/2021       84092619.0  1834675.0  47313005.0
# 01/02/2021       84718978.0  1843108.0  47614297.0
# 01/03/2021       85251774.0  1850449.0  47882779.0
# 01/04/2021       85805892.0  1860598.0  48173187.0
# 01/05/2021       86546014.0  1875953.0  48488548.0
# ...                     ...        ...         ...
# 12/27/2020       80912611.0  1771659.0  45717710.0
# 12/28/2020       81408934.0  1781415.0  46016136.0
# 12/29/2020       82073362.0  1796786.0  46369231.0
# 12/30/2020       82834592.0  1811843.0  46757476.0
# 12/31/2020       83559601.0  1825012.0  47032627.0
#
# [494 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
plt.figure(figsize=(4,3))
sns.lineplot(data=df_time, x='ObservationDate', y='Confirmed', label='Confirmed')
plt.title("Graph based on Obervation date vs Confirmed")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.lineplot(data=df_time, x='ObservationDate', y='Deaths', label='Deaths')
plt.title("Graph based on Obervation date vs Deaths")
plt.show()

# %%
df["Province/State"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# SNo                0
# ObservationDate    0
# Province/State     0
# Country/Region     0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0
# dtype: int64

# %%
df_country = df.groupby('Country/Region').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})

# %%
df_country
# Out:
#                                  Confirmed    Deaths   Recovered
# Country/Region
#  Azerbaijan                            1.0       0.0         0.0
# ('St. Martin',)                        2.0       0.0         0.0
# Afghanistan                     17026442.0  669075.0  13464399.0
# Albania                         19768869.0  375955.0  13945256.0
# Algeria                         27684358.0  834464.0  18959299.0
# ...                                    ...       ...         ...
# West Bank and Gaza              41819444.0  440378.0  37003116.0
# Yemen                             962066.0  237613.0    506523.0
# Zambia                          13493953.0  205990.0  12625626.0
# Zimbabwe                         6484581.0  237234.0   5594887.0
# occupied Palestinian territory        25.0       0.0         0.0
#
# [229 rows x 3 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x= df_country.index, y= 'Confirmed', data=df_country)
plt.title("Bar Graph")
plt.show()

# %%
df['Deaths'].value_counts()
# Out:
# Deaths
# 0.0        32417
# 1.0         9799
# 2.0         6921
# 3.0         6107
# 6.0         4153
#            ...
# 26172.0        1
# 50388.0        1
# 21467.0        1
# 13355.0        1
# 15268.0        1
# Name: count, Length: 20089, dtype: int64

# %%
df['Deaths'].sum()
# Out:
# 624013017.0

# %%
correlation_data = df[['Confirmed', 'Deaths', 'Recovered']]
correlation_matrix = correlation_data.corr()
correlation_matrix
# Out:
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.888416   0.633479
# Deaths      0.888416  1.000000   0.538416
# Recovered   0.633479  0.538416   1.000000

# %%
df['Confirmed']=pd.to_numeric(df['Confirmed'])

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df['Confirmed'].value_counts()
# Out:
# Confirmed
# 0.0         4741
# 1.0         2439
# 13.0        1237
# 18.0        1047
# 3.0          934
#             ...
# 42170.0        1
# 379593.0       1
# 106410.0       1
# 48582.0        1
# 391559.0       1
# Name: count, Length: 107146, dtype: int64

# %%
df['Recovered']=pd.to_numeric(df['Recovered'])

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df['Recovered'].value_counts()
# Out:
# Recovered
# 0.0         68529
# 1.0          2189
# 13.0         1120
# 2.0          1042
# 18.0          971
#             ...
# 80425.0         1
# 116001.0        1
# 114379.0        1
# 24774.0         1
# 83790.0         1
# Name: count, Length: 74541, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
total_country=df.groupby("Country/Region").agg({'Confirmed':'sum', 'Deaths':'sum', 'Recovered':'sum'})

# %%
total_country
# Out:
#                                  Confirmed    Deaths   Recovered
# Country/Region
#  Azerbaijan                            1.0       0.0         0.0
# ('St. Martin',)                        2.0       0.0         0.0
# Afghanistan                     17026442.0  669075.0  13464399.0
# Albania                         19768869.0  375955.0  13945256.0
# Algeria                         27684358.0  834464.0  18959299.0
# ...                                    ...       ...         ...
# West Bank and Gaza              41819444.0  440378.0  37003116.0
# Yemen                             962066.0  237613.0    506523.0
# Zambia                          13493953.0  205990.0  12625626.0
# Zimbabwe                         6484581.0  237234.0   5594887.0
# occupied Palestinian territory        25.0       0.0         0.0
#
# [229 rows x 3 columns]

# %%
total_country.value_counts()
# Out:
# Confirmed     Deaths       Recovered
# 1.000000e+00  0.0          0.0            7
# 3.000000e+00  0.0          0.0            5
# 2.000000e+00  0.0          0.0            3
# 2.100000e+01  0.0          0.0            3
# 4.000000e+00  0.0          0.0            2
#                                          ..
# 2.379802e+06  32100.0      2162473.0      1
# 2.387030e+06  25809.0      2221218.0      1
# 2.388966e+06  7481.0       1707503.0      1
# 2.399352e+06  57538.0      2089375.0      1
# 6.049146e+09  123303762.0  503370956.0    1
# Name: count, Length: 212, dtype: int64

# %%
total_country.head()
# Out:
#                   Confirmed    Deaths   Recovered
# Country/Region
#  Azerbaijan             1.0       0.0         0.0
# ('St. Martin',)         2.0       0.0         0.0
# Afghanistan      17026442.0  669075.0  13464399.0
# Albania          19768869.0  375955.0  13945256.0
# Algeria          27684358.0  834464.0  18959299.0

# %%
top_countries=total_country.sort_values(by='Deaths', ascending=False).head(10)

# %%
top_countries
# Out:
#                    Confirmed       Deaths     Recovered
# Country/Region
# US              6.049146e+09  123303762.0  5.033710e+08
# Brazil          2.653588e+09   72624610.0  2.313677e+09
# India           3.226768e+09   44424723.0  2.900590e+09
# Mexico          4.604637e+08   43005509.0  3.617802e+08
# UK              7.837944e+08   29171984.0  2.327572e+06
# Italy           6.366943e+08   26000702.0  4.877998e+08
# France          8.551890e+08   22720818.0  6.940743e+07
# Spain           6.491118e+08   19065104.0  6.119362e+07
# Russia          9.305488e+08   18363719.0  7.907057e+08
# Iran            4.009098e+08   15744407.0  3.268130e+08

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Country/Region', data=df, color='salmon')
plt.title('Countries by COVID-19 Deaths')
plt.xlabel('Country/Region')
plt.ylabel('Number of Deaths')
plt.show()
