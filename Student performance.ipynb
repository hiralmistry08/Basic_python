# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\hiral\Downloads\student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.shape
# Out:
# (649, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
cat=[]
con=[]

for i in df.columns:
    if df[i].dtype=="object":
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic']

# %%
con
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
for i in con:
    print(f"Mean value of {i} is {df[i].mean()}")
# Out:
# Mean value of age is 16.7442218798151
# Mean value of Medu is 2.514637904468413
# Mean value of Fedu is 2.3066255778120186
# Mean value of traveltime is 1.568567026194145
# Mean value of studytime is 1.9306625577812018
# Mean value of failures is 0.2218798151001541
# Mean value of famrel is 3.930662557781202
# Mean value of freetime is 3.180277349768875
# Mean value of goout is 3.184899845916795
# Mean value of Dalc is 1.50231124807396
# Mean value of Walc is 2.280431432973806
# Mean value of health is 3.536209553158706
# Mean value of absences is 3.6594761171032357
# Mean value of G1 is 11.399075500770415
# Mean value of G2 is 11.570107858243452
# Mean value of G3 is 11.906009244992296

# %%
df['Medu'].isnull().sum()
# Out:
# 0

# %%
print("Number of duplicates:", df.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
age_dis = df['age'].value_counts().sort_index()

# %%
age_dis
# Out:
# age
# 15    112
# 16    177
# 17    179
# 18    140
# 19     32
# 20      6
# 21      2
# 22      1
# Name: count, dtype: int64

# %%
gender_dis=df['sex'].value_counts()

# %%
gender_dis
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
age_dis,gender_dis
# Out:
# (age
#  15    112
#  16    177
#  17    179
#  18    140
#  19     32
#  20      6
#  21      2
#  22      1
#  Name: count, dtype: int64,
#  sex
#  F    383
#  M    266
#  Name: count, dtype: int64)

# %%
grade_cols = ['G1', 'G2', 'G3']
grade_dis = df[grade_cols].describe()

# %%
grade_dis
# Out:
#                G1          G2          G3
# count  649.000000  649.000000  649.000000
# mean    11.399076   11.570108   11.906009
# std      2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000
# 25%     10.000000   10.000000   10.000000
# 50%     11.000000   11.000000   12.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   19.000000

# %%
df_grades = df.groupby('studytime').agg({'G1': 'sum', 'G2': 'sum', 'G3': 'sum'})

# %%
df_grades
# Out:
#              G1    G2    G3
# studytime
# 1          2227  2269  2299
# 2          3519  3557  3688
# 3          1205  1241  1283
# 4           447   442   457

# %%
df_ab = df.groupby('absences').agg({'G1': 'sum', 'G2': 'sum', 'G3': 'sum'})

# %%
df_ab
# Out:
#             G1    G2    G3
# absences
# 0         2901  2908  2938
# 1          143   143   149
# 2         1275  1288  1341
# 3           70    73    73
# 4         1019  1062  1117
# 5          126   136   141
# 6          570   575   594
# 7           36    39    39
# 8          446   460   488
# 9           61    65    68
# 10         244   250   257
# 11          52    56    56
# 12         115   120   121
# 13          13    14    14
# 14          83    80    83
# 15          25    21    22
# 16         100    99   103
# 18          33    35    37
# 21          22    23    23
# 22          20    18    16
# 24           9     8     9
# 26           7     8     8
# 30          14    15    16
# 32          14    13    14

# %%
df_correlation = df[['studytime', 'failures', 'absences']]
df_correlation_data = df_correlation.corr()
df_correlation_data
# Out:
#            studytime  failures  absences
# studytime   1.000000 -0.147441 -0.118389
# failures   -0.147441  1.000000  0.122779
# absences   -0.118389  0.122779  1.000000

# %%
df_correlation_grades= df[['G1','G2','G3']]
df_data= df_correlation_grades.corr()
df_data
# Out:
#           G1        G2        G3
# G1  1.000000  0.864982  0.826387
# G2  0.864982  1.000000  0.918548
# G3  0.826387  0.918548  1.000000

# %%
df_correlation_data1= df_correlation_data,df_data.corr()
df_correlation_data1
# Out:
# (           studytime  failures  absences
#  studytime   1.000000 -0.147441 -0.118389
#  failures   -0.147441  1.000000  0.122779
#  absences   -0.118389  0.122779  1.000000,
#            G1        G2        G3
#  G1  1.000000 -0.655782 -0.962506
#  G2 -0.655782  1.000000  0.426406
#  G3 -0.962506  0.426406  1.000000)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(4,3))
sns.lineplot(data=df, x='studytime', y='failures')
plt.title("Graph based on Study time vs Failures")
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.lineplot(data=df, x='absences', y='failures')
plt.title("Graph based on Absence vs Failures")
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.heatmap(df_correlation_data, annot=True, cmap='Purples', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.heatmap(df_data, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(4,3))
p=df['school'].value_counts()
plt.pie(p,labels=p.index,autopct="%0.2f%%", colors=['Blue', 'orange'])
plt.title("School Distribution")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='absences',data=df, color='green')
plt.title("Distribution of Absences")
plt.show()
